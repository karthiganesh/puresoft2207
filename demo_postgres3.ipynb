# %%
import psycopg2
import getpass
import pandas as pd

# %%
s_db='sgnxrfie'
s_user='sgnxrfie'
s_pwd = 'xLS2nfGGP1aSJyBhg94fXqtqOuKM1MET'
s_host = 'tiny.db.elephantsql.com'
conn = psycopg2.connect(
   database=s_db, user=s_user, password=s_pwd, host=s_host
)

# %%
df_iris = pd.read_sql('select * from iris', con=conn)
df_iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df_iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df_iris[["Species","SepalWidthCm"]]
# Out:
#             Species  SepalWidthCm
# 0       Iris-setosa           3.5
# 1       Iris-setosa           3.0
# 2       Iris-setosa           3.2
# 3       Iris-setosa           3.1
# 4       Iris-setosa           3.6
# ..              ...           ...
# 145  Iris-virginica           3.0
# 146  Iris-virginica           2.5
# 147  Iris-virginica           3.0
# 148  Iris-virginica           3.4
# 149  Iris-virginica           3.0
#
# [150 rows x 2 columns]

# %%
df_iris.SepalLengthCm
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SepalLengthCm, Length: 150, dtype: float64

# %%
df_iris[40:41]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 40  41            5.0           3.5            1.3           0.3  Iris-setosa

# %%
df_iris.loc[[45,55,101]]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 45    46            4.8           3.0            1.4           0.3
# 55    56            5.7           2.8            4.5           1.3
# 101  102            5.8           2.7            5.1           1.9
#
#              Species
# 45       Iris-setosa
# 55   Iris-versicolor
# 101   Iris-virginica

# %%
df_iris[df_iris["SepalWidthCm"]==2.8]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 54    55            6.5           2.8            4.6           1.5
# 55    56            5.7           2.8            4.5           1.3
# 71    72            6.1           2.8            4.0           1.3
# 73    74            6.1           2.8            4.7           1.2
# 76    77            6.8           2.8            4.8           1.4
# 99   100            5.7           2.8            4.1           1.3
# 114  115            5.8           2.8            5.1           2.4
# 121  122            5.6           2.8            4.9           2.0
# 122  123            7.7           2.8            6.7           2.0
# 126  127            6.2           2.8            4.8           1.8
# 128  129            6.4           2.8            5.6           2.1
# 130  131            7.4           2.8            6.1           1.9
# 132  133            6.4           2.8            5.6           2.2
# ...

# %%
df_iris[df_iris['Species']=='Iris-versicolor'].plot.scatter(x='SepalLengthCm',y='PetalLengthCm')
df_iris[df_iris['Species']=='Iris-setosa'].plot.scatter(x='SepalLengthCm',y='PetalLengthCm')
df_iris[df_iris['Species']=='Iris-virginica'].plot.scatter(x='SepalLengthCm',y='PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>
